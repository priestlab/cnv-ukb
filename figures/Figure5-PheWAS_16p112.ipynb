# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import *
import os

# %%
os.system("for f in $(find /oak/stanford/groups/mrivas/ukbb24983/cnv/gwas/ -name '*.linear' -o -name '*.hybrid' | grep white_british); do phe=$(echo $f | awk -F'.' '{print $2}'); awk -v v1='16:28818541-29043450_-' -v v2='16:29596230-30208637_-' -v p=$phe -v OFS='\t' '(($3 == v1) || ($3 == v2) && $NF < 0.01 && $NF !~ /NA/){print $3,p,$(NF-4),$(NF-3),$(NF-2),$(NF-1),$(NF)}' $f; done > /oak/stanford/groups/jpriest/cnv_ukb/gwas/chr16q112.two-var-phewas.v2.tsv")
# Out:
# 0

# %%
phenos = pd.read_table("/oak/stanford/groups/jpriest/cnv_ukb/gwas/chr16q112.two-var-phewas.v2.tsv",
                       names=["CNV","PHENO","N","BETA","SE","TSTAT","P"])

phenos['BIN'] = phenos['PHENO'].apply(lambda x: 'QT' not in x and 'INI' not in x)
phenos['BETA'] = phenos.apply(lambda x: np.log(x['BETA']) if x['BIN'] else x['BETA'], axis=1)  

with open("/oak/stanford/groups/mrivas/users/magu/repos/rivas-lab/ukbb-tools/05_gbe/icdinfo.txt", "r") as i:
    names = {line.split()[0]:line.split()[2] for line in i}
    
phenos['NAME'] = phenos['PHENO'].apply(lambda x: names.get(x) if x in names 
                                                 else names.get(x.replace('QT_FC', 'INI')) if x.replace('QT_FC','INI') in names 
                                                 else names.get(x.replace('BIN_FC','HC')))
phenos['-log10P'] = phenos['P'].apply(lambda x:-np.log10(x))

phenos.head(15)
# Out:
# /home/users/magu/.local/lib/python2.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in log
#   """
#                        CNV     PHENO       N      BETA        SE     TSTAT  \
# 0   16:28818541-29043450_-  INI23112  327630  0.703353  0.165145  4.258990
# 1   16:29596230-30208637_-  INI23112  327630  1.043160  0.137866  7.566450
# 2   16:28818541-29043450_-  INI23104  327650  0.906749  0.206511  4.390800
# 3   16:29596230-30208637_-  INI23104  327650  1.322250  0.172399  7.669700
# 4   16:28818541-29043450_-  INI23130  327346  0.417243  0.129021  3.233920
# 5   16:28818541-29043450_-  INI23113  327622  0.484962  0.132471  3.660900
# 6   16:28818541-29043450_-  INI24019  328014  0.203229  0.206449  0.984400
# 7   16:28818541-29043450_-  INI23106  327822 -0.549811  0.157913 -3.481740
# 8   16:29596230-30208637_-  INI23106  327822 -0.456874  0.131836 -3.465460
# 9   16:28818541-29043450_-  INI23108  327833 -0.783956  0.189060 -4.146600
# 10  16:29596230-30208637_-  INI23108  327833 -0.503850  0.157842 -3.192120
# 11  16:28818541-29043450_-  INI24003  328800  0.180005  0.207052  0.869368
# 12  16:29596230-30208637_-  INI24003  328800  0.466684  0.165502  2.819810
# 13  16:28818541-29043450_-  INI24006  305421  0.224872  0.221367  1.015830
# 14  16:28818541-29043450_-  INI24008  305421  0.422336  0.223247  1.891790
#
#                P    BIN                                             NAME  \
# 0   2.054110e-05  False                             Leg_fat_mass_(right)
# 1   3.845420e-14  False                             Leg_fat_mass_(right)
# 2   1.129670e-05  False                            Body_mass_index_(BMI)
# 3   1.728690e-14  False                            Body_mass_index_(BMI)
# 4   1.221150e-03  False                             Trunk_predicted_mass
# 5   2.513710e-04  False                        Leg_fat-free_mass_(right)
# 6   3.249190e-01  False    Particulate_matter_air_pollution_(pm10);_2007
# 7   4.982410e-04  False                          Impedance_of_whole_body
# 8   5.293910e-04  False                          Impedance_of_whole_body
# 9   3.375330e-05  False                          Impedance_of_leg_(left)
# 10  1.412470e-03  False                          Impedance_of_leg_(left)
# 11  3.846460e-01  False             Nitrogen_dioxide_air_pollution;_2010
# 12  4.805560e-03  False             Nitrogen_dioxide_air_pollution;_2010
# 13  3.097100e-01  False   Particulate_matter_air_pollution_(pm2.5);_2010
# 14  5.852000e-02  False  Particulate_matter_air_pollution_2.5-10um;_2010
#
#       -log10P
# 0    4.687376
# 1   13.415056
# 2    4.947048
# 3   13.762283
# 4    2.913231
# 5    3.599685
# 6    0.488225
# 7    3.302561
# 8    3.276223
# 9    4.471684
# 10   2.850021
# 11   0.414939
# 12   2.318256
# 13   0.509045
# 14   1.232696

# %%
print(str(phenos['NAME'].isnull().sum()) + " unnamed phenotypes!")
print("continuing with remaining {}!".format((~phenos['NAME'].isnull()).sum()))
# Out:
# 0 unnamed phenotypes!
# continuing with remaining 3590!

# %%
phenos[(phenos['NAME'].isnull()) & (phenos['P'] < 1e-4)].sort_values('P').head(50)
# Out:
# Empty DataFrame
# Columns: [CNV, PHENO, N, BETA, SE, TSTAT, P, BIN, NAME, -log10P]
# Index: []

# %%
phenos = phenos[~phenos['NAME'].isnull() & 
                (phenos['PHENO'] != "INI23098") & 
                (phenos['PHENO'] != "INI23104") & 
                (phenos['PHENO'] != "HC10002443")]

# %%
phenos[(phenos['P'] < 9e-6)].sort_values(['CNV','P'])
# Out:
#                          CNV           PHENO       N      BETA        SE  \
# 3494  16:28818541-29043450_-        INI30720  318651  1.201360  0.188790
# 3039  16:28818541-29043450_-     INI10030720  315192  1.253430  0.208302
# 3003  16:28818541-29043450_-     INI10030725  315192  1.231940  0.208277
# 86    16:28818541-29043450_-        INI30300  319018  1.090720  0.201808
# 425   16:28818541-29043450_-        INI30290  319018  1.040610  0.203724
# 813   16:28818541-29043450_-   MED1140871506  333280  5.233368  1.035240
# 718   16:28818541-29043450_-        INI30250  319193  1.016270  0.201243
# 871   16:28818541-29043450_-   MED1140852756  333280  5.072370  1.031870
# 540   16:28818541-29043450_-        INI30240  319192  0.973695  0.203783
# 333   16:28818541-29043450_-   MED1140860802  333280  4.943412  1.037020
# 1412  16:28818541-29043450_-        INI21002  332357  0.830745  0.178906
# 2262  16:28818541-29043450_-   MED1000000513  333280  4.751718  1.029840
# 1603  16:28818541-29043450_-   MED1140860690  333280  4.747407  1.039070
# 1329  16:28818541-29043450_-        INI21001  332246  0.922206  0.202185
# 3039           Cystatin_C_covariate_and_statin_adjusted   8.750853
# 3003                      Cystatin_C_covariate_adjusted   8.478321
# 86                High_light_scatter_reticulocyte_count   7.187407
# 425          High_light_scatter_reticulocyte_percentage   6.486928
# 813                                          ketoprofen   6.366594
# 718                                  Reticulocyte_count   6.354416
# 871                                           vitamin_a   6.053249
# 540                             Reticulocyte_percentage   5.751948
# 333                                 coversyl_2mg_tablet   5.728103
# 1412                                             Weight   5.465061
# 2262                                 ketoprofen_generic   5.403521
# 1603                                 cardura_1mg_tablet   5.309556
# 1329                              Body_mass_index_(BMI)   5.293461
# 135                                 Waist_circumference   5.175045
# 2816                                  myasthenia_gravis   5.061234
# 136                                 Waist_circumference  21.449994
# 977                         Forced_vital_capacity_(FVC)  16.178697
# 1330                              Body_mass_index_(BMI)  15.474019
# 44                           Leg_fat_percentage_(right)  15.160199
# 74                            Leg_fat_percentage_(left)  14.301513
# 228                          Peak_expiratory_flow_(PEF)  14.206894
# 21                            Arm_fat_percentage_(left)  13.917919
# 50                                  Body_fat_percentage  13.748024
# 1                                  Leg_fat_mass_(right)  13.415056
# 67                                  Leg_fat_mass_(left)  12.946392
# 2357                           Diabetes_Mellitus_Type_2  12.753093
# 47                           Arm_fat_percentage_(right)  12.692887
# 651         Forced_expiratory_volume_in_1-second_(FEV1)  12.137624
# 1686                                PEF_predicted_ratio  11.937941
# ...                                                 ...        ...
# 1722                       Diabetes_diagnosed_by_doctor   8.203975
# 773                        Diabetes_diagnosed_by_doctor   8.042500
# 3004                      Cystatin_C_covariate_adjusted   7.630172
# 1413                                             Weight   7.212755
# 3040           Cystatin_C_covariate_and_statin_adjusted   7.186311
# 1747            Index_of_Multiple_Deprivation_(England)   7.042439
# 1645  Forced_expiratory_volume_in_1-second_(FEV1),_B...   6.877479
# 3082  Glycated_haemoglobin_HbA1c_covariate_and_stati...   6.876933
# 3079      Glycated_haemoglobin_HbA1c_covariate_adjusted   6.763035
# 3471                          Hand_grip_strength_(left)   6.692872
# 1777                             Income_score_(England)   6.618042
# 2620                                respiratory_failure   6.498020
# 3027              C_reactive_protein_covariate_adjusted   6.469793
# 3001   C_reactive_protein_covariate_and_statin_adjusted   6.234740
# 2515                                 Usual_walking_pace   6.215366
# 2627                                   abdominal_hernia   6.188000
# 1775                         Employment_score_(England)   6.031020
# 3475                          Gamma_glutamyltransferase   5.838890
# 2779                             essential_hypertension   5.669081
# 1856                 Living_environment_score_(England)   5.535897
# 3555                                              IGF-1   5.449218
# 1715                            Current_tobacco_smoking   5.446273
# 1070                                     Sitting_height   5.417344
# 1779                             Health_score_(England)   5.330453
# 2374                                Cerebral_Infarction   5.149546
# 2792                                chronic_skin_ulcers   5.136026
# 3071                 SHBG_covariate_and_statin_adjusted   5.081449
# 2120                                 disulfiram_generic   5.065860
# 480                        avandamet_1mg_/_500mg_tablet   5.061899
# 554                           Prospective_memory_result   5.048611
#
# [73 rows x 10 columns]

# %%
# hack the fact that beta/se for QTs is unitful
def standardize_coefs(row, phe_path):
    if phe_path is None:
        return None, None
    sd = pd.read_table(phe_path, sep='\s+', na_values=-9, header=None, index_col=None).iloc[:,-1].std()
    return row[['BETA', 'SE']]/sd

def get_phe_path(phe_id):
    with open('/oak/stanford/groups/mrivas/users/minneker/phenotype_ref/phe_app_path.tsv', 'r') as f:
        for line in f:
            if line.split()[0] == phe_id:
                return line.split()[-1]
    return None

# %%
# do the plot
filter_kw = lambda s: all([i not in s for i in ['doctor','left','right','percentage','Best','adjusted']])

y_ht = int(0.4*24) + 2
fig  = plt.figure(figsize=(10, y_ht), dpi=300)
grid = plt.GridSpec(y_ht, 10, hspace=0.3)


for cnv_ix, cnv in enumerate(["16:28818541-29043450_-", "16:29596230-30208637_-"]):
    # select significant data, truncate visualization
    data = phenos.loc[(~phenos['NAME'].isnull()) & 
                      (phenos['NAME'].apply(filter_kw))].query('CNV==@cnv & P < 9e-6').copy()
    
    # apply the hack from the above cell
    # data[['S_BETA', 'S_SE']] = data.apply(lambda x: x[['BETA', 'SE']] if x['BIN'] 
    #                                                else standardize_coefs(x, get_phe_path(x['PHENO'])), axis=1)
    data[['S_BETA','S_SE']] = data[['BETA','SE']]
    
    data = data.query('S_SE < 1').sort_values('P').head(50).copy()
    # group by QT/BIN status, plus fat measurement for second CNV
    order = [irow[0] for irow in sorted([irow for irow in data.iterrows()], 
                                         key=lambda (i,x): -x['P'] - 100*x['BIN'])] 

    # title
    fig.text(0.5, 0.9, '16p11.2 deletion PheWAS', horizontalalignment='center')
    
    # p-values
    if cnv_ix == 0:
        xb = int(0.3 * data.shape[0]) + 1
        ax = fig.add_subplot(grid[:xb,:4])
    else:
        ax = fig.add_subplot(grid[xb:,:4])
    ax.plot([data.loc[i,'-log10P'] for i in order], list(range(len(order))), 'ko')
    ax.set_ylim(-0.5,len(order)-0.5)
    ax.set_yticks(list(range(len(order)))) 
    ax.set_yticklabels(list(map(lambda s:s[0].upper() + s[1:].replace('_',' '), [data.loc[i,'NAME'] for i in order])))
    if cnv_ix == 1:
        ax.set_xlabel('-log10(P)')
    else:
        ax.set_xticklabels(['' for _ in ax.get_xticklabels()])
    ax.set_xlim(3,28)

    # betas
    if cnv_ix == 0:
        ax = fig.add_subplot(grid[:xb,4:])
    else:
        ax = fig.add_subplot(grid[xb:,4:])
    ax.errorbar(x=[data.loc[i,'S_BETA'] for i in order], 
                y=list(range(len(order))),
                xerr=[data.loc[i,'S_SE'] for i in order],
                linestyle='', marker='D')
    ax.set_ylim(-0.5,len(order)-0.5)
    ax.set_yticks(list(range(len(order))))
    ax.set_yticklabels(['' for _ in order])
    if cnv_ix == 1:
        ax.set_xlabel('LOR or BETA')
    else:
        ax.set_xticklabels(['' for _ in ax.get_xticklabels()])
    ax.set_xlim(-1.5,4.5)
    ax.set_ylabel('\n'+cnv[:-2], rotation=270)
    ax.yaxis.set_label_position("right")

    # dash line for betas
    plt.plot([0,0], ax.get_ylim(), 'k--', linewidth=1)

fig.text(-0.25, 0.855, 'A', fontsize=20), fig.text(.91, 0.855, 'C', fontsize=20)
fig.text(-0.25, 0.715, 'B', fontsize=20), fig.text(.91, 0.715, 'D', fontsize=20)
plt.show()

# %%
phenos.query('PHENO == "INI21001"')
# Out:
#                          CNV     PHENO       N      BETA        SE    TSTAT  \
# 1329  16:28818541-29043450_-  INI21001  332246  0.922206  0.202185  4.56121
# 1330  16:29596230-30208637_-  INI21001  332246  1.347050  0.165077  8.16016
#
#                  P    BIN                   NAME    -log10P
# 1329  5.087900e-06  False  Body_mass_index_(BMI)   5.293461
# 1330  3.357230e-16  False  Body_mass_index_(BMI)  15.474019

# %%
phenos.loc[(~phenos['NAME'].isnull()) & (phenos['P'] < 6e-6) &
                 (phenos['NAME'].apply(filter_kw))]
# Out:
#                          CNV          PHENO       N      BETA        SE  \
# 16    16:29596230-30208637_-       INI23128  327437  1.071850  0.173134
# 18    16:29596230-30208637_-       INI23100  327118  1.123900  0.168074
# 86    16:28818541-29043450_-       INI30300  319018  1.090720  0.201808
# 136   16:29596230-30208637_-          INI48  332743  1.415520  0.146170
# 228   16:29596230-30208637_-        INI3064  305942 -1.151170  0.147586
# 333   16:28818541-29043450_-  MED1140860802  333280  4.943412  1.037020
# 455   16:29596230-30208637_-          INI49  332703  1.009420  0.166255
# 551   16:29596230-30208637_-         INI189  332888  0.993810  0.163803
# 651   16:29596230-30208637_-        INI3063  305942 -0.963570  0.134308
# 718   16:28818541-29043450_-       INI30250  319193  1.016270  0.201243
# 813   16:28818541-29043450_-  MED1140871506  333280  5.233368  1.035240
# 871   16:28818541-29043450_-  MED1140852756  333280  5.072370  1.031870
# 977   16:29596230-30208637_-        INI3062  305942 -1.089030  0.130360
# 1070  16:29596230-30208637_-       INI20015  332597 -0.571335  0.123646
# 1101  16:29596230-30208637_-          INI50  332584 -0.792599  0.115250
# 1329  16:28818541-29043450_-       INI21001  332246  0.922206  0.202185
# 1330  16:29596230-30208637_-       INI21001  332246  1.347050  0.165077
# 1412  16:28818541-29043450_-       INI21002  332357  0.830745  0.178906
# 1413  16:29596230-30208637_-       INI21002  332357  0.791041  0.146078
# 1603  16:28818541-29043450_-  MED1140860690  333280  4.747407  1.039070
# 1686  16:29596230-30208637_-     INI1003064  305174 -0.955975  0.134434
# 1715  16:29596230-30208637_-  QT_FC10001239  333116  0.425517  0.091814
# 1747  16:29596230-30208637_-       INI26410  285678  1.004730  0.187989
# 1775  16:29596230-30208637_-       INI26412  285678  0.907198  0.184924
# 1777  16:29596230-30208637_-       INI26411  285678  0.960565  0.185986
# 1779  16:29596230-30208637_-       INI26413  285678  0.854733  0.186661
# 3001  4.99705  5.824520e-07  False
# 3003  5.91490  3.324140e-09  False
# 3004  5.58467  2.343300e-08  False
# 3027  5.10047  3.390060e-07  False
# 3039  6.01736  1.774790e-09  False
# 3040  5.40428  6.511620e-08  False
# 3079  5.22681  1.725700e-07  False
# 3082  5.27512  1.327600e-07  False
# 3475  4.81822  1.449140e-06  False
# 3494  6.36347  1.975110e-10  False
# 3495  6.51293  7.380660e-11  False
# 3503  6.30066  2.967610e-10  False
# 3555 -4.63594  3.554530e-06  False
# 3586  6.05641  1.393480e-09  False
#
#                                                    NAME    -log10P
# 16                                       Trunk_fat_mass   9.222497
# 18                                  Whole_body_fat_mass  10.641570
# 86                High_light_scatter_reticulocyte_count   7.187407
# 136                                 Waist_circumference  21.449994
# 228                          Peak_expiratory_flow_(PEF)  14.206894
# 333                                 coversyl_2mg_tablet   5.728103
# 455                                   Hip_circumference   8.896655
# 551           Townsend_deprivation_index_at_recruitment   8.884826
# 651         Forced_expiratory_volume_in_1-second_(FEV1)  12.137624
# 718                                  Reticulocyte_count   6.354416
# 813                                          ketoprofen   6.366594
# 871                                           vitamin_a   6.053249
# 977                         Forced_vital_capacity_(FVC)  16.178697
# 1070                                     Sitting_height   5.417344
# 1101                                    Standing_height  11.213589
# 1329                              Body_mass_index_(BMI)   5.293461
# 1330                              Body_mass_index_(BMI)  15.474019
# 1412                                             Weight   5.465061
# 1413                                             Weight   7.212755
# 1603                                 cardura_1mg_tablet   5.309556
# 1686                                PEF_predicted_ratio  11.937941
# 1715                            Current_tobacco_smoking   5.446273
# 1747            Index_of_Multiple_Deprivation_(England)   7.042439
# 1775                         Employment_score_(England)   6.031020
# 1777                             Income_score_(England)   6.618042
# 1779                             Health_score_(England)   5.330453
# 1856                 Living_environment_score_(England)   5.535897
# 2262                                 ketoprofen_generic   5.403521
# 2357                           Diabetes_Mellitus_Type_2  12.753093
# 2515                                 Usual_walking_pace   6.215366
# 2620                                respiratory_failure   6.498020
# 2627                                   abdominal_hernia   6.188000
# 2779                             essential_hypertension   5.669081
# 2908                                           diabetes  10.685313
# 3001   C_reactive_protein_covariate_and_statin_adjusted   6.234740
# 3003                      Cystatin_C_covariate_adjusted   8.478321
# 3004                      Cystatin_C_covariate_adjusted   7.630172
# 3027              C_reactive_protein_covariate_adjusted   6.469793
# 3039           Cystatin_C_covariate_and_statin_adjusted   8.750853
# 3040           Cystatin_C_covariate_and_statin_adjusted   7.186311
# 3079      Glycated_haemoglobin_HbA1c_covariate_adjusted   6.763035
# 3082  Glycated_haemoglobin_HbA1c_covariate_and_stati...   6.876933
# 3475                          Gamma_glutamyltransferase   5.838890
# 3494                                         Cystatin_C   9.704409
# 3495                                         Cystatin_C  10.131905
# 3503                       Glycated_haemoglobin_(HbA1c)   9.527593
# 3555                                              IGF-1   5.449218
# 3586                                 C-reactive_protein   8.855899
