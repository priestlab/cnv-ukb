# %%
import numpy as np
import pandas as pd
from scipy.stats import ttest_ind
import time

# %%
zs = pd.read_table('cnv_constraint_zscores_20190430.tsv', names=['Gene','z','pLI'], index_col='Gene')
zs.head()
# Out:
#               z       pLI
# Gene
# BRCA2  3.402038  0.991096
# BRCA1  2.570469  0.984025
# APC    2.085995  0.945645
# ATM    1.242243  0.989235
# MSH2   1.240663  0.988295

# %%
sets = pd.read_table('/oak/stanford/groups/jpriest/cnv_ukb/resources/HPO_pheno_to_gene.txt', skiprows=0,
                     names=['hpoID','hpolabel','geneID','Gene'])
sets.head()
# Out:
#         hpoID                                  hpolabel  geneID   Gene
# 0  HP:0001459                        1-3 toe syndactyly    2737   GLI3
# 1  HP:0006088  1-5 finger complete cutaneous syndactyly   64327  LMBR1
# 2  HP:0010708                     1-5 finger syndactyly    6469    SHH
# 3  HP:0010708                     1-5 finger syndactyly   64327  LMBR1
# 4  HP:0010713                        1-5 toe syndactyly    2737   GLI3

# %%
sets['hpoID'].value_counts().shape
# Out:
# (8524,)

# %%
load = True
if load:
    hpo_t = pd.read_table("cnv_constraint_hpo_enrichment_20190430.tsv")
else:
    hpo_t = pd.DataFrame()
    t = time.time()
    for hpo in sets['hpoID'].value_counts().index:
        # select rows
        in_set = sets.query('hpoID == @hpo and Gene in @zs.index')
        out_of_set = sets.query('hpoID != @hpo and Gene in @zs.index')
        if in_set.shape[0] == 0 or out_of_set.shape[0] == 0:
            continue
        # select genes
        in_set_z = zs.loc[in_set['Gene'],'z']
        out_of_set_z = zs.loc[out_of_set['Gene'],'z']
        # compute mean shift, t-test p-value
        deltaZ = in_set_z.mean() - out_of_set_z.mean()
        _,p = ttest_ind(in_set_z.values, out_of_set_z.values, equal_var=False, nan_policy='omit')
        # append
        hpo_t = hpo_t.append([[hpo, in_set.iloc[0,:]['hpolabel'], deltaZ, p, in_set_z.shape[0]]])
        if hpo_t.shape[0] % 200 == 0:
            print(hpo_t.shape[0], time.time()-t)
            t=time.time()
    hpo_t.columns = ['hpoID','hpoLabel','deltaZ','pValue','nGenes']
    hpo_t.to_csv('cnv_constraint_hpo_enrichment_20190430.tsv', sep='\t')

hpo_t.head()
# Out:
#         hpoID                                  hpoLabel    deltaZ    pValue  \
# 0  HP:0000707         Abnormality of the nervous system -0.007672  0.009988
# 1  HP:0012638  Abnormality of nervous system physiology -0.007689  0.014391
# 2  HP:0000152               Abnormality of head or neck -0.004238  0.233858
# 3  HP:0000234                   Abnormality of the head -0.004255  0.235575
# 4  HP:0000924        Abnormality of the skeletal system -0.006123  0.088247
#
#    nGenes
# 0    2619
# 1    2433
# 2    2115
# 3    2094
# 4    2047

# %%
hpo_t['pValue'] = hpo_t['pValue'].astype(float)

# %%
hpo_t.query('nGenes >= 5 and deltaZ > 0').sort_values('pValue').head(20)
# Out:
#            hpoID                                hpoLabel    deltaZ    pValue  \
# 1178  HP:0002034               Abnormality of the rectum  0.091344  0.005468
# 910   HP:0100006  Neoplasm of the central nervous system  0.084712  0.005929
# 452   HP:0011792                   Neoplasm by histology  0.065458  0.006319
# 549   HP:0002027                          Abdominal pain  0.084144  0.006739
# 1321  HP:0100834         Neoplasm of the large intestine  0.206365  0.006946
# 1612  HP:0100273                   Neoplasm of the colon  0.277430  0.007167
# 904   HP:0010787                        Genital neoplasm  0.133163  0.008309
# 730   HP:0008069                    Neoplasm of the skin  0.064637  0.008358
# 973   HP:0100242                                 Sarcoma  0.084586  0.008506
# 573   HP:0000953           Hyperpigmentation of the skin  0.079611  0.008726
# 708   HP:0007379     Neoplasm of the genitourinary tract  0.098904  0.009468
# 1093  HP:0100568        Neoplasm of the endocrine system  0.098258  0.009500
# 776   HP:0004375          Neoplasm of the nervous system  0.064810  0.009648
# 1509  HP:0030063                Neuroepithelial neoplasm  0.149086  0.010027
# 1459  HP:0030060                 Nervous tissue neoplasm  0.145911  0.010284
# 1460  HP:0030061                Neuroectodermal neoplasm  0.145911  0.010284
# 691   HP:0002250     Abnormal large intestine morphology  0.092780  0.010350
# 1106  HP:0010785                        Gonadal neoplasm  0.151483  0.011309
# 1374  HP:0100615                        Ovarian neoplasm  0.207854  0.011374
# 1864  HP:0003003                            Colon cancer  0.336048  0.012941
#
#       nGenes
# 1178      74
# 910      107
# 452      228
# 549      177
# 1321      67
# 1612      49
# 904      102
# 730      140
# 973      103
# 573      178
# 708      139
# 1093      86
# 776      133
# 1509      53
# 1459      54
# 1460      54
# 691      146
# 1106      79
# 1374      57
# 1864      37

# %%
hpo_t.query('nGenes >= 5 and deltaZ < 0').sort_values('pValue').head(50)
# Out:
#            hpoID                                           hpoLabel    deltaZ  \
# 225   HP:0000648                                      Optic atrophy -0.028272
# 651   HP:0012072                                           Aciduria -0.036503
# 614   HP:0001344                                      Absent speech -0.034383
# 208   HP:0012795                      Abnormality of the optic disc -0.026035
# 1019  HP:0009136            Duplication involving bones of the feet -0.044283
# 832   HP:0003355                                      Aminoaciduria -0.035638
# 1048  HP:0001829                                   Foot polydactyly -0.043610
# 545   HP:0010442                                        Polydactyly -0.032821
# 330   HP:0005280                             Depressed nasal bridge -0.026340
# 1119  HP:0001162                         Postaxial hand polydactyly -0.035859
# 872   HP:0002098                               Respiratory distress -0.031543
# 758   HP:0002803                             Congenital contracture -0.039506
# 845   HP:0002804                 Arthrogryposis multiplex congenita -0.044961
# 323   HP:0012447                               Abnormal myelination -0.025186
# 709   HP:0001161                                   Hand polydactyly -0.036818
# 879   HP:0100259                              Postaxial polydactyly -0.031563
# 784   HP:0011220                                 Prominent forehead -0.028556
# 1614  HP:0009833     Abnormal middle phalanx morphology of the hand -0.049197
# 521   HP:0010864                    Intellectual disability, severe -0.033679
# 1208  HP:0000194                                         Open mouth -0.056514
# 705   HP:0011400                           Abnormal CNS myelination -0.032713
# 419   HP:0000556                                  Retinal dystrophy -0.024817
# 277   HP:0001311          Abnormal nervous system electrophysiology -0.025537
# 1371  HP:0010579                              Cone-shaped epiphysis -0.043933
# 953   HP:0003498                     Disproportionate short stature -0.032277
# 435   HP:0001272                                 Cerebellar atrophy -0.021313
# 1470  HP:0100257                                       Ectrodactyly -0.050898
# 1634  HP:0009843  Aplasia/Hypoplasia of the middle phalanges of ... -0.048390
# 446   HP:0002020                            Gastroesophageal reflux -0.030116
# 1493  HP:0001171                                         Split hand -0.048350
# 1405  HP:0001992                                   Organic aciduria -0.036550
# 1315  HP:0100258                               Preaxial polydactyly -0.048618
# 1129  HP:0011815                                        Cephalocele -0.029945
# 1130  HP:0002084                                      Encephalocele -0.029945
# 1756  HP:0003429                                CNS hypomyelination -0.033280
# 1150  HP:0200134                           Epileptic encephalopathy -0.031529
# 1372  HP:0006829                          Severe muscular hypotonia -0.039879
# 150   HP:0001251                                             Ataxia -0.018976
# 392   HP:0000501                                           Glaucoma -0.023773
# 603   HP:0000662                                         Nyctalopia -0.027301
# 138   HP:0004305                              Involuntary movements -0.018202
# 1462  HP:0002323                                        Anencephaly -0.045268
# 443   HP:0030044                       Flexion contracture of digit -0.024717
# 2275  HP:0005435                           Impaired T cell function -0.087010
# 618   HP:0011338                         Abnormality of mouth shape -0.037946
# 510   HP:0005930                Abnormality of epiphysis morphology -0.029195
# 331   HP:0030178  Abnormality of central nervous system electrop... -0.026166
# 2427  HP:0012762                      Cerebral white matter atrophy -0.035491
# 1224  HP:0001850                    Abnormality of the tarsal bones -0.030149
# 1701  HP:0011840                   Abnormality of T cell physiology -0.058611
#
#             pValue  nGenes
# 225   5.787128e-13     430
# 651   3.258807e-12     155
# 614   2.544988e-10     158
# 208   3.251769e-10     467
# 1019  4.473983e-09      92
# 832   7.014999e-09     115
# 1048  1.315878e-08      88
# 545   4.196554e-08     182
# 330   4.609781e-08     303
# 1119  6.691444e-08      80
# 872   9.298491e-08     106
# 758   9.772703e-08     120
# 845   1.298762e-07     102
# 323   1.378331e-07     318
# 709   1.798595e-07     135
# 879   1.936862e-07     106
# 784   3.646785e-07     122
# 1614  4.841070e-07      44
# 521   5.679883e-07     185
# 1208  6.686574e-07      61
# 705   7.054619e-07     147
# 419   8.032898e-07     234
# 277   8.216947e-07     362
# 1371  8.307135e-07      58
# 953   1.160476e-06      95
# 435   1.193136e-06     235
# 1470  1.245956e-06      50
# 1634  1.656292e-06      42
# 446   2.298428e-06     212
# 1493  2.405590e-06      49
# 1405  3.236982e-06      56
# 1315  3.999616e-06      61
# 1129  4.194930e-06      79
# 1130  4.194930e-06      79
# 1756  4.943743e-06      41
# 1150  6.265016e-06      77
# 1372  7.425345e-06      57
# 150   8.561779e-06     630
# 392   8.572504e-06     252
# 603   8.892543e-06     157
# 138   9.053138e-06     641
# 1462  9.718452e-06      52
# 443   1.062020e-05     209
# 2275  1.076791e-05      24
# 618   1.260140e-05     146
# 510   1.672015e-05     199
# 331   1.690843e-05     289
# 2427  1.864271e-05      21
# 1224  2.151057e-05      69
# 1701  2.182912e-05      38

# %%
hpo_t.query('deltaZ > 0 and pValue < 0.01').sort_values('deltaZ', ascending=False).head(20)
# Out:
#            hpoID                                hpoLabel    deltaZ    pValue  \
# 6280  HP:0006778     Benign genitourinary tract neoplasm  1.165369  0.004459
# 6141  HP:0006719    Benign gastrointestinal tract tumors  1.165369  0.004459
# 6137  HP:0030410               Sebaceous gland carcinoma  1.165369  0.004459
# 5318  HP:0006758     Malignant genitourinary tract tumor  1.073453  0.007271
# 1612  HP:0100273                   Neoplasm of the colon  0.277430  0.007167
# 1321  HP:0100834         Neoplasm of the large intestine  0.206365  0.006946
# 904   HP:0010787                        Genital neoplasm  0.133163  0.008309
# 708   HP:0007379     Neoplasm of the genitourinary tract  0.098904  0.009468
# 1093  HP:0100568        Neoplasm of the endocrine system  0.098258  0.009500
# 1178  HP:0002034               Abnormality of the rectum  0.091344  0.005468
# 910   HP:0100006  Neoplasm of the central nervous system  0.084712  0.005929
# 973   HP:0100242                                 Sarcoma  0.084586  0.008506
# 549   HP:0002027                          Abdominal pain  0.084144  0.006739
# 573   HP:0000953           Hyperpigmentation of the skin  0.079611  0.008726
# 5364  HP:0011939         3-4 finger cutaneous syndactyly  0.076933  0.000902
# 452   HP:0011792                   Neoplasm by histology  0.065458  0.006319
# 776   HP:0004375          Neoplasm of the nervous system  0.064810  0.009648
# 730   HP:0008069                    Neoplasm of the skin  0.064637  0.008358
# 5129  HP:0011784      Thyrotoxicosis with diffuse goiter  0.036587  0.009869
#
#       nGenes
# 6280       2
# 6141       2
# 6137       2
# 5318       3
# 1612      49
# 1321      67
# 904      102
# 708      139
# 1093      86
# 1178      74
# 910      107
# 973      103
# 549      177
# 573      178
# 5364       3
# 452      228
# 776      133
# 730      140
# 5129       2

# %%
hpo_t.query('deltaZ < 0 and pValue < 0.01').sort_values('deltaZ').head(10)
# Out:
#            hpoID                                 hpoLabel    deltaZ    pValue  \
# 4717  HP:0006549  Unilateral primary pulmonary dysgenesis -0.175750  0.000000
# 4742  HP:0011590                       Double aortic arch -0.175750  0.000000
# 5626  HP:0006699            Premature atrial contractions -0.175750  0.000000
# 6223  HP:0040266   Proximal upper limb muscle hypertrophy -0.175749  0.000000
# 6210  HP:0040265            Upper limb muscle hypertrophy -0.175749  0.000000
# 6529  HP:0040278                             Prolactinoma -0.175749  0.000000
# 6682  HP:0040025           Clinodactyly of the 4th finger -0.175749  0.000000
# 6098  HP:0040217                  Elevated hemoglobin A1c -0.175749  0.000000
# 5512  HP:0012398                         Peripheral edema -0.169074  0.000428
# 3965  HP:0001664                       Torsade de pointes -0.158521  0.000093
#
#       nGenes
# 4717       4
# 4742       4
# 5626       3
# 6223       2
# 6210       2
# 6529       2
# 6682       2
# 6098       2
# 5512       3
# 3965       7

# %%
hpo_t.query('deltaZ > 0 and pValue < 0.01 and nGenes < 100').sort_values('deltaZ', ascending=False).head(10)
# Out:
#            hpoID                              hpoLabel    deltaZ    pValue  \
# 6137  HP:0030410             Sebaceous gland carcinoma  1.165369  0.004459
# 6141  HP:0006719  Benign gastrointestinal tract tumors  1.165369  0.004459
# 6280  HP:0006778   Benign genitourinary tract neoplasm  1.165369  0.004459
# 5318  HP:0006758   Malignant genitourinary tract tumor  1.073453  0.007271
# 1612  HP:0100273                 Neoplasm of the colon  0.277430  0.007167
# 1321  HP:0100834       Neoplasm of the large intestine  0.206365  0.006946
# 1093  HP:0100568      Neoplasm of the endocrine system  0.098258  0.009500
# 1178  HP:0002034             Abnormality of the rectum  0.091344  0.005468
# 5364  HP:0011939       3-4 finger cutaneous syndactyly  0.076933  0.000902
# 5129  HP:0011784    Thyrotoxicosis with diffuse goiter  0.036587  0.009869
#
#       nGenes
# 6137       2
# 6141       2
# 6280       2
# 5318       3
# 1612      49
# 1321      67
# 1093      86
# 1178      74
# 5364       3
# 5129       2

# %%
go_t = pd.read_table('cnv_burden_go-enrichment_20190430.tsv', 
                     names=['goID','deltaZ','pValue','goLabel','nGenes']).dropna()
go_t.head()
# Out:
#          goID    deltaZ    pValue  \
# 3  GO:0018916  0.391665  0.000324
# 4  GO:0034199  0.021870  0.439410
# 5  GO:0034198  0.051697  0.225169
# 6  GO:0034197  0.054295  0.821962
# 8  GO:0098831  0.032418  0.397019
#
#                                          goLabel  nGenes
# 3                 nitrobenzene metabolic process       5
# 4        activation of protein kinase A activity       7
# 5     cellular response to amino acid starvation      50
# 6                         triglyceride transport       9
# 8  presynaptic active zone cytoplasmic component      14

# %%
go_t.query('nGenes >= 5 and deltaZ > 0').sort_values('pValue').head(10)
# Out:
#              goID    deltaZ        pValue  \
# 6229   GO:0000137  0.408569  7.143106e-30
# 3072   GO:0045095  0.259425  8.197704e-30
# 6877   GO:0031436  1.456164  2.181880e-28
# 15679  GO:0005515  0.070732  5.522635e-23
# 12187  GO:0000800  0.464194  1.476577e-21
# 15366  GO:0031424  0.181551  1.501647e-20
# 855    GO:0032301  1.098655  7.979989e-20
# 5029   GO:0008194  0.352454  1.064619e-18
# 17039  GO:0052697  0.471476  4.533896e-18
# 11256  GO:0070200  0.976704  1.578191e-17
#
#                                                  goLabel  nGenes
# 6229                                  Golgi cis cisterna      26
# 3072                                    keratin filament      95
# 6877                                 BRCA1-BARD1 complex       9
# 15679                                    protein binding   78231
# 12187                                    lateral element      14
# 15366                                     keratinization     182
# 855                                    MutSalpha complex       6
# 5029                    UDP-glycosyltransferase activity      22
# 17039                         xenobiotic glucuronidation      15
# 11256  establishment of protein localization to telomere       7

# %%
go_t.query('deltaZ > 0 and pValue < 0.01 and nGenes < 100').sort_values('deltaZ', ascending=False).head(10)
# Out:
#              goID    deltaZ        pValue  \
# 8108   GO:0010484  1.721401  1.326390e-48
# 15169  GO:1990426  1.708483  7.182820e-48
# 6877   GO:0031436  1.456164  2.181880e-28
# 9336   GO:0044818  1.307222  5.650977e-28
# 4539   GO:0032137  1.232403  7.028652e-25
# 855    GO:0032301  1.098655  7.979989e-20
# 11256  GO:0070200  0.976704  1.578191e-17
# 15436  GO:0051572  0.877742  1.830890e-18
# 11344  GO:0043009  0.876516  2.060368e-18
# 5148   GO:0033600  0.844449  2.741474e-22
#
#                                                  goLabel  nGenes
# 8108               H3 histone acetyltransferase activity       2
# 15169  mitotic recombination-dependent replication fo...       2
# 6877                                 BRCA1-BARD1 complex       9
# 9336                  mitotic G2/M transition checkpoint       2
# 4539                     guanine/thymine mispair binding       2
# 855                                    MutSalpha complex       6
# 11256  establishment of protein localization to telomere       7
# 15436   negative regulation of histone H3-K4 methylation       3
# 11344                     chordate embryonic development       3
# 5148   negative regulation of mammary gland epithelia...       4

# %%
go_t.query('deltaZ > 0 and pValue < 0.01 and nGenes > 10').sort_values('deltaZ', ascending=False).head(10)
# Out:
#              goID    deltaZ        pValue  \
# 1698   GO:0070531  0.837759  3.654163e-14
# 8578   GO:0005131  0.529813  2.687257e-13
# 3157   GO:0072425  0.506647  7.990895e-07
# 17039  GO:0052697  0.471476  4.533896e-18
# 12187  GO:0000800  0.464194  1.476577e-21
# 4589   GO:0006298  0.464057  1.623888e-06
# 15548  GO:0016446  0.429991  6.515977e-14
# 17038  GO:0052696  0.423800  6.560641e-11
# 12826  GO:0042954  0.423320  9.526873e-15
# 6074   GO:0070383  0.419576  2.883237e-06
#
#                                                  goLabel  nGenes
# 1698                                     BRCA1-A complex      19
# 8578                     growth hormone receptor binding      17
# 3157   signal transduction involved in G2 DNA damage ...      16
# 17039                         xenobiotic glucuronidation      15
# 12187                                    lateral element      14
# 4589                                     mismatch repair      58
# 15548      somatic hypermutation of immunoglobulin genes      11
# 17038                          flavonoid glucuronidation      13
# 12826                   lipoprotein transporter activity      11
# 6074                            DNA cytosine deamination      16

# %%
go_t.query('nGenes >= 5 and deltaZ < 0').sort_values('pValue').head(10)
# Out:
#              goID    deltaZ    pValue  \
# 561    GO:0070507 -0.006137  0.019911
# 2109   GO:0060307 -0.010503  0.039781
# 17161  GO:0038191 -0.004804  0.042861
# 14471  GO:0042297 -0.051704  0.044773
# 105    GO:0006627 -0.057200  0.059360
# 902    GO:0006346 -0.011886  0.071145
# 7838   GO:0051247 -0.019965  0.076872
# 3455   GO:0004707 -0.015312  0.077174
# 970    GO:0031731 -0.062286  0.078628
# 9233   GO:0005007 -0.038676  0.089501
#
#                                                  goLabel  nGenes
# 561    regulation of microtubule cytoskeleton organiz...      31
# 2109   regulation of ventricular cardiac muscle cell ...      22
# 17161                                 neuropilin binding      20
# 14471                                     vocal learning       8
# 105    protein processing involved in protein targeti...       8
# 902            methylation-dependent chromatin silencing      13
# 7838    positive regulation of protein metabolic process      12
# 3455                                 MAP kinase activity      46
# 970                      CCR6 chemokine receptor binding       6
# 9233   fibroblast growth factor-activated receptor ac...      18

# %%
go_t.query('nGenes >= 5 and deltaZ < 0').sort_values('deltaZ').head(10)
# Out:
#              goID    deltaZ    pValue  \
# 1621   GO:0003720 -0.096531  0.447253
# 11367  GO:2001027 -0.084196  0.139595
# 13633  GO:0004514 -0.080284  0.489368
# 7771   GO:0000703 -0.079864  0.352417
# 10134  GO:0004415 -0.079809  0.185115
# 10784  GO:0004348 -0.077592  0.379018
# 11309  GO:0061408 -0.075166  0.337678
# 5863   GO:0086011 -0.072555  0.098663
# 970    GO:0031731 -0.062286  0.078628
# 105    GO:0006627 -0.057200  0.059360
#
#                                                  goLabel  nGenes
# 1621                                 telomerase activity      15
# 11367  negative regulation of endothelial cell chemot...       5
# 13633  nicotinate-nucleotide diphosphorylase (carboxy...       7
# 7771   oxidized pyrimidine nucleobase lesion DNA N-gl...       5
# 10134                 hyalurononglucosaminidase activity      28
# 10784                        glucosylceramidase activity       5
# 11309  positive regulation of transcription from RNA ...      12
# 5863     membrane repolarization during action potential      15
# 970                      CCR6 chemokine receptor binding       6
# 105    protein processing involved in protein targeti...       8
